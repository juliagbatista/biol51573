# %% [markdown]
# ## understanding `append`

# %%
# start fresh with new groups
jackson5 = ['jackie', 'tito', 'jermaine', 'marlon', 'michael']
destiny  = ['beyonce', 'kelly', 'michelle']
top40    = ['taylorswift', 'postmalone']

#make a list that will be a supergroup
super = []
super.append(destiny) #append means add to the end of the list
super.append(jackson5)
super.append(top40)
print(len(super)) #how many groups are in the supergroup
print(super) #show the supergroup
# Out:
# 3
# [['beyonce', 'kelly', 'michelle'], ['jackie', 'tito', 'jermaine', 'marlon', 'michael'], ['taylorswift', 'postmalone']]

# %% [markdown]
# ## looping over a list

# %%
# loop over 'destiny'
#basic structure of a for loop
print(destiny)
for i in destiny:
    print(i)
# Out:
# ['beyonce', 'kelly', 'michelle']
# beyonce
# kelly
# michelle

# %% [markdown]
# ## executing a nested `for` loop

# %%
# loop over destiny, as they are in inside super
for i in super[0]:
    print(i)

print() #blank line 

# loop over jackson5, as they are in inside super
for i in super[1]:
    print(i)

print()

# loop over top40, as they are in inside super
for i in super[2]:
    print(i)


print()
print("here's the nested for loop")
print()

#make some counters
band_num = 0
member_num = 0


# loop within a loop
#for band in super:
    #increment our band counter
    #band_num += 1 # same as doing band_num = band_num + 1
    
    #member_num = 0 #reset member_num to 0 for each band before we loop over the members of the band


    #for member in band:
        #member_num += 1
        #print(f"{member} is member {member_num} of band {band_num}") 

#other way 
for band in super:
    #increment our band counter
    band_num += 1 # same as doing band_num = band_num + 1
    
    member_num = 1 #reset member_num to 1 for each band before we loop over the members of the band, so that the first member of each band is member 1, not member 0


    for member in band:
        
        print(f"{member} is member {member_num} of band {band_num}") 
        member_num += 1 #we add after the print statement so that the first member of each band is member 1, not member 2
# Out:
# beyonce
# kelly
# michelle
#
# jackie
# tito
# jermaine
# marlon
# michael
#
# taylorswift
# postmalone
#
# here's the nested for loop
#
# beyonce is member 1 of band 1
# kelly is member 2 of band 1
# michelle is member 3 of band 1
# jackie is member 1 of band 2
# tito is member 2 of band 2
# jermaine is member 3 of band 2
# marlon is member 4 of band 2
# michael is member 5 of band 2
# taylorswift is member 1 of band 3
# postmalone is member 2 of band 3

# %% [markdown]
# ### retrieve the index _and_ the value with `enumerate()`

# %%
# lots of flexibility with enumerate()
presidents = ["George Washington", "John Adams", "Thomas Jefferson", "James Madison", "James Monroe", "John Quincy Adams", "Andrew Jackson", "Martin Van Buren", "William Henry Harrison", "John Tyler", "James Knox Polk", "Zachary Taylor", "Millard Fillmore", "Franklin Pierce", "James Buchanan", "Abraham Lincoln", "Andrew Johnson", "Ulysses S. Grant", "Rutherford Birchard Hayes", "James Abram Garfield", "Chester Alan Arthur", "Grover Cleveland", "Benjamin Harrison", "Grover Cleveland", "William McKinley", "Theodore Roosevelt", "William Howard Taft", "Woodrow Wilson", "Warren Gamaliel Harding", "Calvin Coolidge", "Herbert Clark Hoover", "Franklin Delano Roosevelt", "Harry S. Truman", "Dwight David Eisenhower", "John Fitzgerald Kennedy", "Lyndon Baines Johnson", "Richard Milhous Nixon", "Gerald Rudolph Ford", "James Earl Carter Jr.", "Ronald Wilson Reagan", "George Herbert Walker Bush", "William Jefferson Clinton", "George Walker Bush", "Barack Hussein Obama", "Donald Trump", "Joe Biden"]

for num, name in enumerate(presidents): #named two variables, enumerate will give us the number and the name for each president in the list
    print(f"President number {num+1} was {name}") #will loop and give us the number and name of each president, we add 1 to num because enumerate starts counting at 0, but we want to start counting at 1 for the presidents
# Out:
# President number 1 was George Washington
# President number 2 was John Adams
# President number 3 was Thomas Jefferson
# President number 4 was James Madison
# President number 5 was James Monroe
# President number 6 was John Quincy Adams
# President number 7 was Andrew Jackson
# President number 8 was Martin Van Buren
# President number 9 was William Henry Harrison
# President number 10 was John Tyler
# President number 11 was James Knox Polk
# President number 12 was Zachary Taylor
# President number 13 was Millard Fillmore
# President number 14 was Franklin Pierce
# President number 15 was James Buchanan
# President number 16 was Abraham Lincoln
# President number 17 was Andrew Johnson
# President number 18 was Ulysses S. Grant
# President number 19 was Rutherford Birchard Hayes
# President number 20 was James Abram Garfield
# President number 21 was Chester Alan Arthur
# President number 22 was Grover Cleveland
# President number 23 was Benjamin Harrison
# ...

# %% [markdown]
# ## loop over a string

# %%
today = "Wednesday"
vowels = "aeiou"

for letter in today:
    if letter not in vowels:
        print(letter,end='')
# Out:
# Wdnsdy
