# %% [markdown]
# # heading
# ## sub heading
# ### sub-sub heading
# #### sub-sub-sub heading
#
# bulleted list:
#
# - michael
# - tito
#
# numbered list:
#
# 1. first
# 2. second
# 3. thrird
# 4. fourth
#
# this is a code block: `phython3 hello_world.py`

# %% [markdown]
# ### here is hello world in python

# %%
print('hello world  ')
print(7+9)
